# %%
def main():
    fh = open('lines.txt')
    for line in fh.readlines():# readlines() method gives us the iterator to iterate through the file
        print(line, end='')
        
    for line in 'Wasindu':
        print(line)    
if __name__ == "__main__": main()

# %% [markdown]
# in python all the container types are iterators<br>
# string is also a container object
