# %%
def main():
    a = 1
    b, c = 25, 6
    print(type(a), a)
    print(b, c)
    d, e = 100, 101
    b, c = d, e
    print(b, c)
    f = (1, 2, 3, 4, 5)
    print(a)
    print(f)

# %%
if __name__ == "__main__":
    main()
